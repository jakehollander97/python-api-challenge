# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

print('Beginning Data Retrieval')
print('---------------------------')

rec_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i%50==0 and i>=50):
        set_count += 1
        rec_count = 0
        
    city_url = url + '&q=' + city
    
    print('Processing Record %s of Set %s | %s' % (rec_count, set_count, city))
    
    rec_count += 1
    
    # runs API request
    try:
        
        city_weather = requests.get(city_url).json() #gets all data from the url in json format
        
        # parse data into necessary info bins
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # make a list with all of the data collected
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # skip the city if there's an error
    except:
        print("City not found. Skipping...")
        pass
              
# finish data scraping process 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | naze
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | ilulissat
# Processing Record 8 of Set 1 | nebug
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | laguna
# Processing Record 12 of Set 1 | yarmouth
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | gimli
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | taltal
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | caravelas
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | khor
# Processing Record 25 of Set 1 | ixtapa
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | san cristobal
# Processing Record 28 of Set 1 | tupelo
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | marfino
# Processing Record 32 of Set 1 | rawson
# Processing Record 33 of Set 1 | bobo dioulasso
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | talnakh
# Processing Record 42 of Set 1 | hokitika
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | saint-pierre
# Processing Record 45 of Set 1 | antequera
# Processing Record 46 of Set 1 | klaksvik
# Processing Record 47 of Set 1 | okhotsk
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 0 of Set 2 | hilo
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | roma
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | mbeya
# Processing Record 7 of Set 2 | bocas del toro
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | nishihara
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | zhezkazgan
# Processing Record 12 of Set 2 | salalah
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | ramsar
# Processing Record 15 of Set 2 | salina cruz
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | mbanza-ngungu
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | kargil
# Processing Record 20 of Set 2 | la palma
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | jiaonan
# Processing Record 23 of Set 2 | hovd
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | dwarka
# Processing Record 26 of Set 2 | berlevag
# Processing Record 27 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | hastings
# Processing Record 30 of Set 2 | baglung
# Processing Record 31 of Set 2 | aswan
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | lesnoy
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | samarai
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | burkhala
# City not found. Skipping...
# Processing Record 39 of Set 2 | kaihua
# Processing Record 40 of Set 2 | chibombo
# Processing Record 41 of Set 2 | bogatyye saby
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | angoche
# Processing Record 45 of Set 2 | christiana
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | mataura
# Processing Record 48 of Set 2 | kendari
# Processing Record 49 of Set 2 | port hedland
# Processing Record 0 of Set 3 | arman
# Processing Record 1 of Set 3 | mantua
# Processing Record 2 of Set 3 | fallon
# Processing Record 3 of Set 3 | belgaum
# Processing Record 4 of Set 3 | albeni
# Processing Record 5 of Set 3 | neuquen
# Processing Record 6 of Set 3 | hofn
# Processing Record 7 of Set 3 | buala
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | beloha
# Processing Record 10 of Set 3 | antrim
# Processing Record 11 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 12 of Set 3 | olafsvik
# Processing Record 13 of Set 3 | lavrentiya
# Processing Record 14 of Set 3 | dhanera
# Processing Record 15 of Set 3 | maceio
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | langsa
# Processing Record 18 of Set 3 | ende
# Processing Record 19 of Set 3 | sembe
# Processing Record 20 of Set 3 | ulladulla
# Processing Record 21 of Set 3 | goksun
# Processing Record 22 of Set 3 | ouesso
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | libreville
# Processing Record 25 of Set 3 | tocopilla
# Processing Record 26 of Set 3 | svetlogorsk
# Processing Record 27 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 3 | port moresby
# Processing Record 29 of Set 3 | maroantsetra
# Processing Record 30 of Set 3 | abengourou
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | saint-augustin
# Processing Record 33 of Set 3 | fort nelson
# Processing Record 34 of Set 3 | beringovskiy
# Processing Record 35 of Set 3 | bay roberts
# Processing Record 36 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 3 | port macquarie
# Processing Record 38 of Set 3 | geraldton
# Processing Record 39 of Set 3 | pokhara
# Processing Record 40 of Set 3 | pemangkat
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | santa cruz de tenerife
# Processing Record 43 of Set 3 | launceston
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | anadyr
# Processing Record 46 of Set 3 | adrar
# Processing Record 47 of Set 3 | hervey bay
# Processing Record 48 of Set 3 | saryozek
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 0 of Set 4 | san rafael
# Processing Record 1 of Set 4 | jardim
# Processing Record 2 of Set 4 | marawi
# Processing Record 3 of Set 4 | tura
# Processing Record 4 of Set 4 | eregli
# Processing Record 5 of Set 4 | mandan
# Processing Record 6 of Set 4 | betare oya
# Processing Record 7 of Set 4 | zhigansk
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | parana
# Processing Record 10 of Set 4 | korla
# Processing Record 11 of Set 4 | verkhnevilyuysk
# Processing Record 12 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 4 | cuamba
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | kobilja glava
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | bottrop
# Processing Record 18 of Set 4 | dhidhdhoo
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | tautira
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | tual
# Processing Record 23 of Set 4 | segovia
# Processing Record 24 of Set 4 | ust-ilimsk
# Processing Record 25 of Set 4 | fairbanks
# Processing Record 26 of Set 4 | sobolevo
# Processing Record 27 of Set 4 | atbasar
# Processing Record 28 of Set 4 | grootfontein
# Processing Record 29 of Set 4 | hurghada
# Processing Record 30 of Set 4 | mogadishu
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | gamba
# Processing Record 33 of Set 4 | melfi
# Processing Record 34 of Set 4 | waverley
# Processing Record 35 of Set 4 | biryusinsk
# Processing Record 36 of Set 4 | vegachi
# Processing Record 37 of Set 4 | kapit
# Processing Record 38 of Set 4 | berdigestyakh
# Processing Record 39 of Set 4 | mackay
# Processing Record 40 of Set 4 | padang
# Processing Record 41 of Set 4 | te anau
# Processing Record 42 of Set 4 | komsomolskiy
# Processing Record 43 of Set 4 | chapais
# Processing Record 44 of Set 4 | husavik
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | tymovskoye
# Processing Record 48 of Set 4 | cooma
# Processing Record 49 of Set 4 | lasa
# Processing Record 0 of Set 5 | tasiilaq
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | iquique
# Processing Record 4 of Set 5 | baykit
# Processing Record 5 of Set 5 | gilleleje
# Processing Record 6 of Set 5 | emerald
# Processing Record 7 of Set 5 | samana
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | basco
# Processing Record 10 of Set 5 | yerbogachen
# Processing Record 11 of Set 5 | haines junction
# Processing Record 12 of Set 5 | bermeo
# Processing Record 13 of Set 5 | marrakesh
# Processing Record 14 of Set 5 | cayenne
# Processing Record 15 of Set 5 | tezu
# Processing Record 16 of Set 5 | dubti
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | elat
# Processing Record 19 of Set 5 | metro
# Processing Record 20 of Set 5 | carbonia
# Processing Record 21 of Set 5 | namatanai
# Processing Record 22 of Set 5 | khash
# Processing Record 23 of Set 5 | shangzhi
# Processing Record 24 of Set 5 | loncoche
# Processing Record 25 of Set 5 | east london
# Processing Record 26 of Set 5 | palafrugell
# Processing Record 27 of Set 5 | narrabri
# Processing Record 28 of Set 5 | llangefni
# Processing Record 29 of Set 5 | broome
# Processing Record 30 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 5 | huarmey
# Processing Record 32 of Set 5 | tandil
# Processing Record 33 of Set 5 | grindavik
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | manggar
# Processing Record 36 of Set 5 | ranfurly
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | riyadh
# Processing Record 40 of Set 5 | tres lagoas
# Processing Record 41 of Set 5 | jalu
# Processing Record 42 of Set 5 | west bay
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | kaitangata
# Processing Record 45 of Set 5 | saldanha
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | rasht
# Processing Record 48 of Set 5 | griffith
# Processing Record 49 of Set 5 | zharkent
# Processing Record 0 of Set 6 | acutzilapan
# City not found. Skipping...
# Processing Record 1 of Set 6 | arraial do cabo
# Processing Record 2 of Set 6 | merauke
# Processing Record 3 of Set 6 | phan thiet
# Processing Record 4 of Set 6 | chapleau
# Processing Record 5 of Set 6 | tondano
# Processing Record 6 of Set 6 | buenos aires
# Processing Record 7 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 8 of Set 6 | mezhdurechensk
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 6 | santa rosa
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | bonavista
# Processing Record 14 of Set 6 | faya
# Processing Record 15 of Set 6 | katsuura
# Processing Record 16 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 6 | tiksi
# Processing Record 18 of Set 6 | margate
# Processing Record 19 of Set 6 | hasaki
# Processing Record 20 of Set 6 | nogent-le-rotrou
# Processing Record 21 of Set 6 | rauma
# Processing Record 22 of Set 6 | bethel
# Processing Record 23 of Set 6 | mareeba
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | ust-nera
# Processing Record 26 of Set 6 | promyshlennyy
# Processing Record 27 of Set 6 | khatanga
# Processing Record 28 of Set 6 | kirkconnel
# Processing Record 29 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 6 | richards bay
# Processing Record 31 of Set 6 | jumla
# Processing Record 32 of Set 6 | zhangjiakou
# Processing Record 33 of Set 6 | kolondieba
# Processing Record 34 of Set 6 | kintampo
# Processing Record 35 of Set 6 | longyearbyen
# Processing Record 36 of Set 6 | georgiyevskoye
# Processing Record 37 of Set 6 | ouidah
# Processing Record 38 of Set 6 | kulhudhuffushi
# Processing Record 39 of Set 6 | marau
# Processing Record 40 of Set 6 | starosubkhangulovo
# Processing Record 41 of Set 6 | two rivers
# Processing Record 42 of Set 6 | silves
# Processing Record 43 of Set 6 | atar
# Processing Record 44 of Set 6 | whitefish
# Processing Record 45 of Set 6 | semey
# Processing Record 46 of Set 6 | sinnamary
# Processing Record 47 of Set 6 | sao joao da barra
# Processing Record 48 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 6 | ancud
# Processing Record 0 of Set 7 | betioky
# Processing Record 1 of Set 7 | carman
# Processing Record 2 of Set 7 | la gaulette
# City not found. Skipping...
# Processing Record 3 of Set 7 | henties bay
# Processing Record 4 of Set 7 | buchanan
# Processing Record 5 of Set 7 | vestmanna
# Processing Record 6 of Set 7 | praia da vitoria
# Processing Record 7 of Set 7 | karratha
# Processing Record 8 of Set 7 | sao filipe
# Processing Record 9 of Set 7 | beaverlodge
# Processing Record 10 of Set 7 | lelystad
# Processing Record 11 of Set 7 | prince rupert
# Processing Record 12 of Set 7 | gogrial
# Processing Record 13 of Set 7 | kiama
# Processing Record 14 of Set 7 | caloundra
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | jurm
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | nantucket
# Processing Record 19 of Set 7 | vanavara
# Processing Record 20 of Set 7 | flinders
# Processing Record 21 of Set 7 | lac du bonnet
# Processing Record 22 of Set 7 | hearst
# Processing Record 23 of Set 7 | narasannapeta
# Processing Record 24 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 25 of Set 7 | gigmoto
# Processing Record 26 of Set 7 | lorengau
# Processing Record 27 of Set 7 | rio brilhante
# Processing Record 28 of Set 7 | rancho santa margarita
# Processing Record 29 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 30 of Set 7 | zaysan
# Processing Record 31 of Set 7 | aloleng
# Processing Record 32 of Set 7 | san felipe
# Processing Record 33 of Set 7 | belmonte
# Processing Record 34 of Set 7 | vila
# Processing Record 35 of Set 7 | santa helena
# Processing Record 36 of Set 7 | qurayyat
# Processing Record 37 of Set 7 | bethal
# Processing Record 38 of Set 7 | puerto lempira
# Processing Record 39 of Set 7 | melton mowbray
# Processing Record 40 of Set 7 | palmer
# Processing Record 41 of Set 7 | lebu
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | ondjiva
# Processing Record 45 of Set 7 | iskateley
# Processing Record 46 of Set 7 | dunedin
# Processing Record 47 of Set 7 | sulangan
# Processing Record 48 of Set 7 | garowe
# Processing Record 49 of Set 7 | terrace
# Processing Record 0 of Set 8 | moquegua
# Processing Record 1 of Set 8 | bardiyah
# Processing Record 2 of Set 8 | mosquera
# Processing Record 3 of Set 8 | statesboro
# Processing Record 4 of Set 8 | gravelbourg
# Processing Record 5 of Set 8 | dikson
# Processing Record 6 of Set 8 | kutum
# Processing Record 7 of Set 8 | rio grande
# Processing Record 8 of Set 8 | uglovka
# Processing Record 9 of Set 8 | baymak
# Processing Record 10 of Set 8 | roebourne
# Processing Record 11 of Set 8 | praia
# Processing Record 12 of Set 8 | carnarvon
# Processing Record 13 of Set 8 | anito
# Processing Record 14 of Set 8 | erzin
# Processing Record 15 of Set 8 | sola
# Processing Record 16 of Set 8 | havoysund
# Processing Record 17 of Set 8 | pemba
# Processing Record 18 of Set 8 | asfi
# Processing Record 19 of Set 8 | mount isa
# Processing Record 20 of Set 8 | karacakoy
# Processing Record 21 of Set 8 | hukuntsi
# Processing Record 22 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 8 | torbay
# Processing Record 24 of Set 8 | strezhevoy
# Processing Record 25 of Set 8 | sitka
# Processing Record 26 of Set 8 | san patricio
# Processing Record 27 of Set 8 | riachao
# Processing Record 28 of Set 8 | boulder
# Processing Record 29 of Set 8 | almaznyy
# Processing Record 30 of Set 8 | inta
# Processing Record 31 of Set 8 | muros
# Processing Record 32 of Set 8 | port elizabeth
# Processing Record 33 of Set 8 | severo-yeniseyskiy
# Processing Record 34 of Set 8 | ugoofaaru
# Processing Record 35 of Set 8 | aykhal
# Processing Record 36 of Set 8 | san luis
# Processing Record 37 of Set 8 | havre-saint-pierre
# Processing Record 38 of Set 8 | auki
# Processing Record 39 of Set 8 | benguela
# Processing Record 40 of Set 8 | ochamchira
# Processing Record 41 of Set 8 | lichinga
# Processing Record 42 of Set 8 | suamico
# Processing Record 43 of Set 8 | nioki
# Processing Record 44 of Set 8 | shingu
# Processing Record 45 of Set 8 | bengkulu
# Processing Record 46 of Set 8 | oudtshoorn
# Processing Record 47 of Set 8 | caucaia
# Processing Record 48 of Set 8 | camacha
# Processing Record 49 of Set 8 | ntcheu
# Processing Record 0 of Set 9 | matay
# Processing Record 1 of Set 9 | necochea
# Processing Record 2 of Set 9 | cabinda
# Processing Record 3 of Set 9 | isilkul
# Processing Record 4 of Set 9 | khandagayty
# Processing Record 5 of Set 9 | dicabisagan
# Processing Record 6 of Set 9 | yambio
# Processing Record 7 of Set 9 | muravlenko
# Processing Record 8 of Set 9 | yulara
# Processing Record 9 of Set 9 | manoel urbano
# Processing Record 10 of Set 9 | america dourada
# Processing Record 11 of Set 9 | myitkyina
# Processing Record 12 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 9 | dzilam gonzalez
# Processing Record 14 of Set 9 | les cayes
# Processing Record 15 of Set 9 | dembi dolo
# Processing Record 16 of Set 9 | hamilton
# Processing Record 17 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 9 | nurota
# Processing Record 19 of Set 9 | potgietersrus
# City not found. Skipping...
# Processing Record 20 of Set 9 | seddon
# Processing Record 21 of Set 9 | wagga wagga
# Processing Record 22 of Set 9 | warrnambool
# Processing Record 23 of Set 9 | avera
# Processing Record 24 of Set 9 | grand-santi
# Processing Record 25 of Set 9 | manadhoo
# Processing Record 26 of Set 9 | lata
# Processing Record 27 of Set 9 | slave lake
# Processing Record 28 of Set 9 | la asuncion
# Processing Record 29 of Set 9 | broken hill
# Processing Record 30 of Set 9 | puerto morazan
# Processing Record 31 of Set 9 | la tuque
# Processing Record 32 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 9 | kropotkin
# Processing Record 34 of Set 9 | kununurra
# Processing Record 35 of Set 9 | norman wells
# Processing Record 36 of Set 9 | banda aceh
# Processing Record 37 of Set 9 | tiznit
# Processing Record 38 of Set 9 | havelock
# Processing Record 39 of Set 9 | lumberton
# Processing Record 40 of Set 9 | mahebourg
# Processing Record 41 of Set 9 | sylacauga
# Processing Record 42 of Set 9 | heyang
# Processing Record 43 of Set 9 | vallenar
# Processing Record 44 of Set 9 | matara
# Processing Record 45 of Set 9 | sibolga
# Processing Record 46 of Set 9 | bara
# Processing Record 47 of Set 9 | hamirpur
# Processing Record 48 of Set 9 | paamiut
# Processing Record 49 of Set 9 | ilo
# Processing Record 0 of Set 10 | jijiga
# Processing Record 1 of Set 10 | san-pedro
# Processing Record 2 of Set 10 | eureka
# Processing Record 3 of Set 10 | waipawa
# Processing Record 4 of Set 10 | nador
# Processing Record 5 of Set 10 | vagur
# Processing Record 6 of Set 10 | moranbah
# Processing Record 7 of Set 10 | mihalt
# Processing Record 8 of Set 10 | corinto
# Processing Record 9 of Set 10 | dubbo
# Processing Record 10 of Set 10 | srednekolymsk
# Processing Record 11 of Set 10 | abha
# Processing Record 12 of Set 10 | luau
# Processing Record 13 of Set 10 | alim
# Processing Record 14 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 10 | oussouye
# Processing Record 16 of Set 10 | maumere
# Processing Record 17 of Set 10 | popova
# Processing Record 18 of Set 10 | honiara
# Processing Record 19 of Set 10 | talagang
# Processing Record 20 of Set 10 | asau
# Processing Record 21 of Set 10 | luderitz
# Processing Record 22 of Set 10 | puerto asis
# Processing Record 23 of Set 10 | maniitsoq
# Processing Record 24 of Set 10 | anloga
# Processing Record 25 of Set 10 | gusau
# Processing Record 26 of Set 10 | ansbach
# Processing Record 27 of Set 10 | ocean city
# Processing Record 28 of Set 10 | trelew
# Processing Record 29 of Set 10 | piacabucu
# Processing Record 30 of Set 10 | georgetown
# Processing Record 31 of Set 10 | clocolan
# Processing Record 32 of Set 10 | bone
# Processing Record 33 of Set 10 | andenes
# Processing Record 34 of Set 10 | makakilo city
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | volodarsk
# Processing Record 37 of Set 10 | wollongong
# Processing Record 38 of Set 10 | vardo
# Processing Record 39 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 10 | bhandara
# Processing Record 41 of Set 10 | labuhan
# Processing Record 42 of Set 10 | xiaoweizhai
# Processing Record 43 of Set 10 | tongren
# Processing Record 44 of Set 10 | teya
# Processing Record 45 of Set 10 | omsukchan
# Processing Record 46 of Set 10 | kamenka
# Processing Record 47 of Set 10 | wanning
# Processing Record 48 of Set 10 | tyukhtet
# Processing Record 49 of Set 10 | guanica
# Processing Record 0 of Set 11 | isangel
# Processing Record 1 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 11 | biskamzha
# Processing Record 3 of Set 11 | constitucion
# Processing Record 4 of Set 11 | bud
# Processing Record 5 of Set 11 | cabo san lucas
# Processing Record 6 of Set 11 | barra
# Processing Record 7 of Set 11 | port augusta
# Processing Record 8 of Set 11 | hvolsvollur
# Processing Record 9 of Set 11 | taoudenni
# Processing Record 10 of Set 11 | ukiah
# Processing Record 11 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 11 | solnechnyy
# Processing Record 13 of Set 11 | sosnovo-ozerskoye
# Processing Record 14 of Set 11 | beoumi
# Processing Record 15 of Set 11 | inongo
# Processing Record 16 of Set 11 | touros
# Processing Record 17 of Set 11 | udachnyy
# Processing Record 18 of Set 11 | hunchun
# Processing Record 19 of Set 11 | rafai
# Processing Record 20 of Set 11 | cherdyn
# Processing Record 21 of Set 11 | saint george
# Processing Record 22 of Set 11 | tolmin
# Processing Record 23 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 11 | kavieng
# Processing Record 25 of Set 11 | beira
# Processing Record 26 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 11 | quesnel
# Processing Record 28 of Set 11 | iwanai
# Processing Record 29 of Set 11 | krasnogorsk
# Processing Record 30 of Set 11 | anori
# Processing Record 31 of Set 11 | kanigoro
# Processing Record 32 of Set 11 | nago
# Processing Record 33 of Set 11 | chokurdakh
# Processing Record 34 of Set 11 | nuzvid
# Processing Record 35 of Set 11 | lima
# Processing Record 36 of Set 11 | ocampo
# Processing Record 37 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 38 of Set 11 | gat
# Processing Record 39 of Set 11 | lesozavodsk
# Processing Record 40 of Set 11 | tabuk
# Processing Record 41 of Set 11 | roslavl
# Processing Record 42 of Set 11 | lagoa
# Processing Record 43 of Set 11 | kandana
# Processing Record 44 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 11 | dolinsk
# Processing Record 46 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 11 | madanapalle
# Processing Record 48 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 11 | gushikawa
# Processing Record 0 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | novosergiyevka
# Processing Record 2 of Set 12 | springdale
# Processing Record 3 of Set 12 | qasigiannguit
# Processing Record 4 of Set 12 | zhuanghe
# Processing Record 5 of Set 12 | nelson bay
# Processing Record 6 of Set 12 | kieta
# Processing Record 7 of Set 12 | nueva loja
# Processing Record 8 of Set 12 | noumea
# Processing Record 9 of Set 12 | matranovak
# Processing Record 10 of Set 12 | palana
# Processing Record 11 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 12 | siocon
# Processing Record 13 of Set 12 | goderich
# Processing Record 14 of Set 12 | ketchikan
# Processing Record 15 of Set 12 | porto novo
# Processing Record 16 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 12 | lagos
# Processing Record 18 of Set 12 | filingue
# Processing Record 19 of Set 12 | iquitos
# Processing Record 20 of Set 12 | shakiso
# Processing Record 21 of Set 12 | tommot
# Processing Record 22 of Set 12 | yotsukaido
# Processing Record 23 of Set 12 | poyarkovo
# Processing Record 24 of Set 12 | los llanos de aridane
# Processing Record 25 of Set 12 | codo
# Processing Record 26 of Set 12 | tombouctou
# Processing Record 27 of Set 12 | ternate
# Processing Record 28 of Set 12 | alice springs
# Processing Record 29 of Set 12 | weiser
# Processing Record 30 of Set 12 | socorro
# Processing Record 31 of Set 12 | grand gaube
# Processing Record 32 of Set 12 | mayo
# Processing Record 33 of Set 12 | oktyabrskoye
# Processing Record 34 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 12 | beroroha
# Processing Record 36 of Set 12 | luxeuil-les-bains
# Processing Record 37 of Set 12 | carutapera
# Processing Record 38 of Set 12 | mulanje
# Processing Record 39 of Set 12 | requena
# Processing Record 40 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 41 of Set 12 | ciudad bolivar
# Processing Record 42 of Set 12 | turukhansk
# Processing Record 43 of Set 12 | port lincoln
# Processing Record 44 of Set 12 | lavumisa
# Processing Record 45 of Set 12 | san jose
# Processing Record 46 of Set 12 | calama
# Processing Record 47 of Set 12 | great yarmouth
# Processing Record 48 of Set 12 | warragul
# Processing Record 49 of Set 12 | sindor
# Processing Record 0 of Set 13 | aleksandrov gay
# Processing Record 1 of Set 13 | kingman
# Processing Record 2 of Set 13 | mweka
# Processing Record 3 of Set 13 | opuwo
# Processing Record 4 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 13 | keila
# Processing Record 6 of Set 13 | ranghulu
# Processing Record 7 of Set 13 | harper
# Processing Record 8 of Set 13 | puerto madero
# Processing Record 9 of Set 13 | alamosa
# Processing Record 10 of Set 13 | betong
# Processing Record 11 of Set 13 | burnie
# Processing Record 12 of Set 13 | armidale
# Processing Record 13 of Set 13 | ballina
# Processing Record 14 of Set 13 | port washington
# Processing Record 15 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 13 | nacala
# Processing Record 17 of Set 13 | nizhniy odes
# Processing Record 18 of Set 13 | sabzevar
# Processing Record 19 of Set 13 | takaka
# Processing Record 20 of Set 13 | formosa do rio preto
# Processing Record 21 of Set 13 | puerto escondido
# Processing Record 22 of Set 13 | urumqi
# Processing Record 23 of Set 13 | fevralsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)


lats = city_data_pd['Lat']
max_temps = city_data_pd['Max Temp']
humidity = city_data_pd['Humidity']
cloudiness = city_data_pd['Cloudiness']
wind_speed = city_data_pd['Wind Speed']

city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          573
# Cloudiness    573
# Country       573
# Date          573
# Humidity      573
# Lat           573
# Lng           573
# Max Temp      573
# Wind Speed    573
# dtype: int64

# %%
city_data_pd.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            naze          40      JP  1585854195        77  28.37  129.48
# 1          avarua          40      CK  1585854196        88 -21.21 -159.78
# 2      butaritari          59      KI  1585854196        76   3.07  172.79
# 3  ribeira grande         100      PT  1585854196        88  38.52  -28.70
# 4          dingle           7      PH  1585854196        83  11.00  122.67
#
#    Max Temp  Wind Speed
# 0     62.60        5.82
# 1     80.60        2.24
# 2     82.94        8.70
# 3     61.41       11.68
# 4     78.13        8.79

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, edgecolor='black', 
            linewidths=1, marker='o', alpha = 0.75,
            label='Cities')

plt.title('Max Temperature (%s) vs City Latitude' % time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('output_data/TempVsLat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, edgecolor='black', 
            linewidths=1, marker='o', alpha = 0.75,
            label='Cities')

plt.title('Humidity (%s) vs City Latitude' % time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('output_data/HumidityVsLat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, edgecolor='black', 
            linewidths=1, marker='o', alpha = 0.75,
            label='Cities')

plt.title('Cloudiness (%s) vs City Latitude' % time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('output_data/CloudinessVsLat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats, wind_speed, edgecolor='black', 
            linewidths=1, marker='o', alpha = 0.75,
            label='Cities')

plt.title('Wind Speed (%s) vs City Latitude' % time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('output_data/WindSpeedVsLat.png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_lin_reg(x_values, y_values, title, text_coord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values*slope + intercept
    line_eq = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, text_coord, fontsize=12, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemi_df = city_data_pd.loc[(city_data_pd['Lat'] >= 0)]
south_hemi_df = city_data_pd.loc[(city_data_pd['Lat'] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Max Temp']

plot_lin_reg(x_values, y_values, 'Max Temp', (0,20))
# Out:
# The r-squared is: -0.9080236338266959

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Max Temp']

plot_lin_reg(x_values, y_values, 'Max Temp', (-50,90))
# Out:
# The r-squared is: 0.682842774621582

# %% [markdown]
# #### The high r-value shows a strong relationship between temperature and latitude

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Humidity']

plot_lin_reg(x_values, y_values, 'Humidity', (50,20))
# Out:
# The r-squared is: 0.294152424866802

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Humidity']

plot_lin_reg(x_values, y_values, 'Humidity', (-18,20))
# Out:
# The r-squared is: 0.0517052258423159

# %% [markdown]
# #### the low r-values show a poor relationship between humidity and latitude

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Cloudiness']

plot_lin_reg(x_values, y_values, 'Cloudiness', (80,10))
# Out:
# The r-squared is: 0.0519633636885023

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Cloudiness']

plot_lin_reg(x_values, y_values, 'Cloudiness', (-50,10))
# Out:
# The r-squared is: 0.27645701565806996

# %% [markdown]
# #### the low r-values show a poor relationship between cloudiness and latitude

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df['Lat']
y_values = north_hemi_df['Wind Speed']

plot_lin_reg(x_values, y_values, 'Wind Speed', (10,30))
# Out:
# The r-squared is: 0.227273474686471

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hemi_df['Lat']
y_values = south_hemi_df['Wind Speed']

plot_lin_reg(x_values, y_values, 'Wind Speed', (-55,15))
# Out:
# The r-squared is: -0.14227742673140928

# %% [markdown]
# #### There is no real relationship between wind speed and the latitude based on the r-values. The only relationship that seems to be indicidant of the hemisphere playing a part is max temp vs latitude
